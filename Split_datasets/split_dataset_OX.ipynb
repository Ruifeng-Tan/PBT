# %% [markdown]
# # README
# This notebook is used to split the dataset.

# %%
import numpy as np
import pickle
import pandas as pd
import numpy as np
import random
import os
from batteryml.data.battery_data import BatteryData
random.seed(2024)
np.random.seed(2024)

# %% [markdown]
# # OX dataset

# %%
# Here is the train_ids provided by BatteryML
data_path = '../dataset/OX'
files = os.listdir(data_path)

test_ratio = 0.2
testing_set = random.sample(files, int(len(files)*0.2))
training_set = [i for i in files if i not in testing_set]

val_ratio = 0.2

validation_set= random.sample(training_set, int(len(training_set)*0.25))
training_set = [i for i in training_set if i not in validation_set]



assert len(training_set) + len(testing_set) + len(validation_set) == len(files)
print(f'training_set: {len(training_set)} {training_set}')
print(f'Val set: {len(validation_set)} {validation_set}')
print(f'Test set: {len(testing_set)} {testing_set}')
# Out:
# training_set: 6 ['OX_1-2_pouch_LCO_40C_0-100_2-1.84C_b.pkl', 'OX_1-3_pouch_LCO_40C_0-100_2-1.84C_c.pkl', 'OX_1-6_pouch_LCO_40C_0-100_2-1.84C_f.pkl', 'OX_1-7_pouch_LCO_40C_0-100_2-1.84C_g.pkl', 'OX_1-4_pouch_LCO_40C_0-100_2-1.84C_d.pkl', 'OX_1-8_pouch_LCO_40C_0-100_2-1.84C_h.pkl']
# Val set: 1 ['OX_1-5_pouch_LCO_40C_0-100_2-1.84C_e.pkl']
# Test set: 1 ['OX_1-1_pouch_LCO_40C_0-100_2-1.84C_a.pkl']
