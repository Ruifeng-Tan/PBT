# %% [markdown]
# # README
# This notebook is used to obtain the embeddings of the domain-knowledge prompt. Then, we can use the embeddings to cluster the samples with K-means.

# %%
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import matplotlib.cm as cm
import matplotlib as mpl
import pickle
import transformers
from matplotlib.lines import Line2D
import seaborn as sns
import json
import torch
from data_provider.data_split_recorder import split_recorder
from Prompts.Mapping_helper import Mapping_helper
from transformers import GPT2Config, GPT2Tokenizer, GPT2Model, AutoTokenizer, AutoModel, AutoConfig, Phi3Config

# %%
generate_for_transformer = False # Set True to save the sequence embeddings of the LLM. Otherwise, only the emebedding of the last token.
cell_names = [i.split('.pkl')[0] for i in split_recorder.MIX_large_train_files]
cell_names
# Out:
# ['UL-PUR_N10-NA7_18650_NCA_23C_0-100_0.5-0.5C_g',
#  'UL-PUR_N15-NA10_18650_NCA_23C_0-100_0.5-0.5C_j',
#  'RWTH_016',
#  'RWTH_045',
#  'RWTH_009',
#  'RWTH_039',
#  'RWTH_046',
#  'RWTH_019',
#  'RWTH_037',
#  'RWTH_013',
#  'RWTH_003',
#  'RWTH_044',
#  'RWTH_026',
#  'RWTH_006',
#  'RWTH_031',
#  'RWTH_036',
#  'RWTH_048',
#  'RWTH_033',
#  'RWTH_021',
#  'RWTH_012',
#  'RWTH_034',
#  'RWTH_018',
#  'RWTH_022',
#  'RWTH_030',
#  'RWTH_028',
#  'RWTH_011',
#  'RWTH_040',
#  'RWTH_041',
#  'RWTH_042',
#  'RWTH_025',
#  'RWTH_047',
#  'RWTH_004',
#  'HUST_1-6',
#  'HUST_2-2',
#  'HUST_1-3',
#  'HUST_6-3',
#  'HUST_1-2',
#  'HUST_3-7',
#  'HUST_3-2',
#  'HUST_10-6',
#  'HUST_3-6',
#  'HUST_5-1',
#  'HUST_10-5',
#  'HUST_6-2',
#  'HUST_6-1',
#  'HUST_8-1',
#  'HUST_10-7',
#  'HUST_1-4',
#  'HUST_5-4',
#  'HUST_1-5',
#  'HUST_6-6',
#  'HUST_5-6',
#  'HUST_6-4',
#  'HUST_9-2',
#  'HUST_10-4',
#  'HUST_5-3',
#  'HUST_7-7',
#  'HUST_3-1',
#  'HUST_4-1',
#  'HUST_4-4',
#  'HUST_4-6',
#  'HUST_8-8',
#  'HUST_2-4',
#  'HUST_9-8',
#  'HUST_9-5',
#  'HUST_3-3',
#  'HUST_1-7',
#  'HUST_4-5',
#  'HUST_9-6',
#  'HUST_1-1',
#  'HUST_4-3',
#  'HUST_2-5',
#  'HUST_4-7',
#  'HUST_7-2',
#  'HUST_8-4',
#  'HUST_3-5',
#  'HUST_2-6',
#  'HUST_8-6',
#  'HUST_7-5',
#  'MATR_b1c5',
#  'MATR_b3c6',
#  'MATR_b1c7',
#  'MATR_b4c18',
#  'MATR_b3c44',
#  'MATR_b3c18',
#  'MATR_b2c12',
#  'MATR_b2c26',
#  'MATR_b4c26',
#  'MATR_b3c40',
#  'MATR_b1c9',
#  'MATR_b2c18',
#  'MATR_b3c17',
#  'MATR_b3c21',
#  'MATR_b2c6',
#  'MATR_b3c45',
#  'MATR_b1c23',
#  'MATR_b2c4',
#  'MATR_b1c35',
#  'MATR_b1c19',
#  'MATR_b2c39',
#  'MATR_b3c26',
#  'MATR_b2c28',
#  'MATR_b2c33',
#  'MATR_b3c39',
#  'MATR_b2c29',
#  'MATR_b3c31',
#  'MATR_b4c42',
#  'MATR_b4c7',
#  'MATR_b2c38',
#  'MATR_b1c41',
#  'MATR_b3c33',
#  'MATR_b4c40',
#  'MATR_b1c17',
#  'MATR_b3c1',
#  'MATR_b4c10',
#  'MATR_b1c33',
#  'MATR_b2c10',
#  'MATR_b3c13',
#  'MATR_b4c37',
#  'MATR_b4c23',
#  'MATR_b4c15',
#  'MATR_b2c0',
#  'MATR_b2c19',
#  'MATR_b4c1',
#  'MATR_b3c8',
#  'MATR_b1c15',
#  'MATR_b4c24',
#  'MATR_b3c15',
#  'MATR_b1c3',
#  'MATR_b1c16',
#  'MATR_b3c3',
#  'MATR_b4c20',
#  'MATR_b4c30',
#  'MATR_b4c25',
#  'MATR_b4c9',
#  'MATR_b1c20',
#  'MATR_b3c14',
#  'MATR_b2c5',
#  'MATR_b3c22',
#  'MATR_b3c16',
#  'MATR_b4c43',
#  'MATR_b4c19',
#  'MATR_b2c31',
#  'MATR_b2c21',
#  'MATR_b4c12',
#  'MATR_b2c36',
#  'MATR_b1c21',
#  'MATR_b2c3',
#  'MATR_b2c37',
#  'MATR_b4c4',
#  'MATR_b2c44',
#  'MATR_b4c34',
#  'MATR_b4c29',
#  'MATR_b3c7',
#  'MATR_b4c21',
#  'MATR_b2c1',
#  'MATR_b1c31',
#  'MATR_b2c14',
#  'MATR_b1c26',
#  'MATR_b4c38',
#  'MATR_b1c42',
#  'MATR_b2c17',
#  'MATR_b3c28',
#  'MATR_b3c10',
#  'MATR_b3c36',
#  'MATR_b3c24',
#  'MATR_b1c6',
#  'MATR_b2c34',
#  'MATR_b3c9',
#  'MATR_b4c14',
#  'MATR_b2c24',
#  'MATR_b2c30',
#  'MATR_b3c4',
#  'MATR_b4c11',
#  'MATR_b2c41',
#  'MATR_b4c8',
#  'MATR_b3c25',
#  'MATR_b1c38',
#  'MATR_b3c27',
#  'MATR_b1c18',
#  'MATR_b2c32',
#  'Stanford_Nova_Regular_228',
#  'Stanford_Nova_Regular_203',
#  'Stanford_Nova_Regular_215',
#  'Stanford_Nova_Regular_225',
#  'Stanford_Nova_Regular_222',
#  'Stanford_Nova_Regular_226',
#  'Stanford_Nova_Regular_221',
#  'Stanford_Nova_Regular_211',
#  'Stanford_Nova_Regular_219',
#  'Stanford_Nova_Regular_229',
#  'Stanford_Nova_Regular_193',
#  'Stanford_Nova_Regular_200',
#  'Stanford_Nova_Regular_205',
#  'Stanford_Nova_Regular_230',
#  'Stanford_Nova_Regular_196',
#  'Stanford_Nova_Regular_216',
#  'Stanford_Nova_Regular_220',
#  'Stanford_Nova_Regular_201',
#  'Stanford_Nova_Regular_Ref_101',
#  'Stanford_Nova_Regular_192',
#  'Stanford_Nova_Regular_208',
#  'Stanford_Nova_Regular_Ref_102',
#  'Stanford_Nova_Regular_210',
#  'Stanford_Nova_Regular_212',
#  'Stanford_Nova_Regular_199',
#  'Tongji1_CY35-05_1-#2',
#  'Tongji1_CY45-05_1-#21',
#  'Tongji1_CY45-05_1-#28',
#  'Tongji2_CY45-05_1-#11',
#  'Tongji1_CY25-1_1-#5',
#  'Tongji1_CY25-1_1-#9',
#  'Tongji1_CY45-05_1-#19',
#  'Tongji3_CY25-05_4-#1',
#  'Tongji1_CY25-05_1-#2',
#  'Tongji3_CY25-05_2-#1',
#  'Tongji1_CY45-05_1-#5',
#  'Tongji1_CY45-05_1-#13',
#  'Tongji1_CY45-05_1-#11',
#  'Tongji1_CY35-05_1-#1',
#  'Tongji1_CY45-05_1-#17',
#  'Tongji2_CY25-05_1-#13',
#  'Tongji1_CY25-1_1-#6',
#  'Tongji2_CY45-05_1-#22',
#  'Tongji1_CY45-05_1-#27',
#  'Tongji2_CY45-05_1-#27',
#  'Tongji1_CY25-05_1-#17',
#  'Tongji2_CY45-05_1-#9',
#  'Tongji3_CY25-05_2-#2',
#  'Tongji1_CY45-05_1-#18',
#  'Tongji3_CY25-05_4-#2',
#  'Tongji1_CY45-05_1-#20',
#  'Tongji1_CY45-05_1-#1',
#  'Tongji2_CY45-05_1-#23',
#  'Tongji2_CY25-05_1-#5',
#  'Tongji2_CY45-05_1-#25',
#  'Tongji1_CY25-05_1-#4',
#  'Tongji1_CY25-05_1-#12',
#  'Tongji1_CY25-05_1-#16',
#  'Tongji1_CY25-05_1-#13',
#  'Tongji2_CY25-05_1-#17',
#  'Tongji1_CY45-05_1-#7',
#  'Tongji1_CY25-025_1-#5',
#  'Tongji2_CY25-05_1-#12',
#  'Tongji1_CY45-05_1-#6',
#  'Tongji3_CY25-05_1-#2',
#  'Tongji3_CY25-05_2-#3',
#  'Tongji2_CY45-05_1-#16',
#  'Tongji1_CY25-05_1-#15',
#  'Tongji1_CY25-025_1-#3',
#  'Tongji2_CY45-05_1-#7',
#  'Tongji2_CY45-05_1-#20',
#  'Tongji1_CY45-05_1-#23',
#  'Tongji2_CY25-05_1-#15',
#  'Tongji2_CY35-05_1-#4',
#  'Tongji1_CY45-05_1-#12',
#  'Tongji2_CY45-05_1-#15',
#  'Tongji1_CY25-05_1-#5',
#  'Tongji2_CY35-05_1-#3',
#  'Tongji1_CY25-05_1-#14',
#  'Tongji1_CY45-05_1-#26',
#  'Tongji1_CY45-05_1-#22',
#  'Tongji2_CY45-05_1-#24',
#  'Tongji1_CY25-05_1-#18',
#  'Tongji1_CY45-05_1-#9',
#  'Tongji1_CY45-05_1-#24',
#  'Tongji1_CY25-1_1-#4',
#  'Tongji2_CY45-05_1-#26',
#  'Tongji3_CY25-05_1-#3',
#  'Tongji1_CY45-05_1-#15',
#  'Tongji1_CY25-025_1-#2',
#  'Tongji2_CY45-05_1-#14',
#  'ISU-ILCC_G23C3',
#  'ISU-ILCC_G64C4',
#  'ISU-ILCC_G50C1',
#  'ISU-ILCC_G36C2',
#  'ISU-ILCC_G7C4',
#  'ISU-ILCC_G16C2',
#  'ISU-ILCC_G13C2',
#  'ISU-ILCC_G29C3',
#  'ISU-ILCC_G41C3',
#  'ISU-ILCC_G39C4',
#  'ISU-ILCC_G36C4',
#  'ISU-ILCC_G28C3',
#  'ISU-ILCC_G18C1',
#  'ISU-ILCC_G58C1',
#  'ISU-ILCC_G8C2',
#  'ISU-ILCC_G16C3',
#  'ISU-ILCC_G27C2',
#  'ISU-ILCC_G22C1',
#  'ISU-ILCC_G43C1',
#  'ISU-ILCC_G53C2',
#  'ISU-ILCC_G32C4',
#  'ISU-ILCC_G44C3',
#  'ISU-ILCC_G38C1',
#  'ISU-ILCC_G61C3',
#  'ISU-ILCC_G43C2',
#  'ISU-ILCC_G20C2',
#  'ISU-ILCC_G17C1',
#  'ISU-ILCC_G33C4',
#  'ISU-ILCC_G60C1',
#  'ISU-ILCC_G27C3',
#  'ISU-ILCC_G45C3',
#  'ISU-ILCC_G18C4',
#  'ISU-ILCC_G50C4',
#  'ISU-ILCC_G1C1',
#  'ISU-ILCC_G19C4',
#  'ISU-ILCC_G49C4',
#  'ISU-ILCC_G3C3',
#  'ISU-ILCC_G19C2',
#  'ISU-ILCC_G52C4',
#  'ISU-ILCC_G31C1',
#  'ISU-ILCC_G47C2',
#  'ISU-ILCC_G43C4',
#  'ISU-ILCC_G47C1',
#  'ISU-ILCC_G40C2',
#  'ISU-ILCC_G20C4',
#  'ISU-ILCC_G6C2',
#  'ISU-ILCC_G32C3',
#  'ISU-ILCC_G41C4',
#  'ISU-ILCC_G60C2',
#  'ISU-ILCC_G64C3',
#  'ISU-ILCC_G9C2',
#  'ISU-ILCC_G49C3',
#  'ISU-ILCC_G46C1',
#  'ISU-ILCC_G30C1',
#  'ISU-ILCC_G29C4',
#  'ISU-ILCC_G50C2',
#  'ISU-ILCC_G51C1',
#  'ISU-ILCC_G55C2',
#  'ISU-ILCC_G17C4',
#  'ISU-ILCC_G50C3',
#  'ISU-ILCC_G25C1',
#  'ISU-ILCC_G4C4',
#  'ISU-ILCC_G13C4',
#  'ISU-ILCC_G46C3',
#  'ISU-ILCC_G38C2',
#  'ISU-ILCC_G34C1',
#  'ISU-ILCC_G45C4',
#  'ISU-ILCC_G27C4',
#  'ISU-ILCC_G35C1',
#  'ISU-ILCC_G21C4',
#  'ISU-ILCC_G24C1',
#  'ISU-ILCC_G40C4',
#  'ISU-ILCC_G42C3',
#  'ISU-ILCC_G39C1',
#  'ISU-ILCC_G14C1',
#  'ISU-ILCC_G61C2',
#  'ISU-ILCC_G63C3',
#  'ISU-ILCC_G23C4',
#  'ISU-ILCC_G36C1',
#  'ISU-ILCC_G57C2',
#  'ISU-ILCC_G55C1',
#  'ISU-ILCC_G4C1',
#  'ISU-ILCC_G7C3',
#  'ISU-ILCC_G12C4',
#  'ISU-ILCC_G34C2',
#  'ISU-ILCC_G7C1',
#  'ISU-ILCC_G51C4',
#  'ISU-ILCC_G4C2',
#  'ISU-ILCC_G44C1',
#  'ISU-ILCC_G46C4',
#  'ISU-ILCC_G42C2',
#  'ISU-ILCC_G28C2',
#  'ISU-ILCC_G12C3',
#  'ISU-ILCC_G51C2',
#  'ISU-ILCC_G62C4',
#  'ISU-ILCC_G30C2',
#  'ISU-ILCC_G28C1',
#  'ISU-ILCC_G56C2',
#  'ISU-ILCC_G23C2',
#  'ISU-ILCC_G52C1',
#  'ISU-ILCC_G37C3',
#  'ISU-ILCC_G34C3',
#  'ISU-ILCC_G57C3',
#  'ISU-ILCC_G32C2',
#  'ISU-ILCC_G38C3',
#  'ISU-ILCC_G18C3',
#  'ISU-ILCC_G10C3',
#  'ISU-ILCC_G40C3',
#  'ISU-ILCC_G14C3',
#  'ISU-ILCC_G1C4',
#  'ISU-ILCC_G29C2',
#  'ISU-ILCC_G17C3',
#  'ISU-ILCC_G45C1',
#  'ISU-ILCC_G62C3',
#  'ISU-ILCC_G31C3',
#  'ISU-ILCC_G25C3',
#  'ISU-ILCC_G44C4',
#  'ISU-ILCC_G4C3',
#  'ISU-ILCC_G44C2',
#  'ISU-ILCC_G62C1',
#  'ISU-ILCC_G30C3',
#  'ISU-ILCC_G56C3',
#  'ISU-ILCC_G47C4',
#  'ISU-ILCC_G25C2',
#  'ISU-ILCC_G42C1',
#  'ISU-ILCC_G20C1',
#  'ISU-ILCC_G59C1',
#  'ISU-ILCC_G38C4',
#  'ISU-ILCC_G9C3',
#  'ISU-ILCC_G35C3',
#  'ISU-ILCC_G8C4',
#  'ISU-ILCC_G53C1',
#  'ISU-ILCC_G30C4',
#  'ISU-ILCC_G20C3',
#  'ISU-ILCC_G9C1',
#  'ISU-ILCC_G21C1',
#  'ISU-ILCC_G3C2',
#  'ISU-ILCC_G5C1',
#  'ISU-ILCC_G1C3',
#  'ISU-ILCC_G62C2',
#  'ISU-ILCC_G58C3',
#  'ISU-ILCC_G21C2',
#  'ISU-ILCC_G28C4',
#  'ISU-ILCC_G24C2',
#  'CALCE_CS2_36',
#  'CALCE_CS2_37',
#  'CALCE_CX2_33',
#  'CALCE_CS2_34',
#  'CALCE_CX2_37',
#  'CALCE_CS2_33',
#  'CALCE_CS2_35',
#  'CALCE_CS2_38',
#  'CALCE_CX2_36',
#  'HNEI_18650_NMC_LCO_25C_0-100_0.5-1.5C_o',
#  'HNEI_18650_NMC_LCO_25C_0-100_0.5-1.5C_p',
#  'HNEI_18650_NMC_LCO_25C_0-100_0.5-1.5C_e',
#  'HNEI_18650_NMC_LCO_25C_0-100_0.5-1.5C_l',
#  'HNEI_18650_NMC_LCO_25C_0-100_0.5-1.5C_b',
#  'HNEI_18650_NMC_LCO_25C_0-100_0.5-1.5C_t',
#  'HNEI_18650_NMC_LCO_25C_0-100_0.5-1.5C_c',
#  'HNEI_18650_NMC_LCO_25C_0-100_0.5-1.5C_a',
#  'HNEI_18650_NMC_LCO_25C_0-100_0.5-1.5C_g',
#  'SNL_18650_NCA_25C_0-100_0.5-0.5C_b',
#  'SNL_18650_NCA_35C_0-100_0.5-1C_b',
#  'SNL_18650_NMC_35C_0-100_0.5-2C_b',
#  'SNL_18650_NMC_25C_0-100_0.5-3C_b',
#  'SNL_18650_NMC_25C_0-100_0.5-1C_a',
#  'SNL_18650_LFP_25C_0-100_0.5-3C_c',
#  'SNL_18650_NCA_25C_0-100_0.5-2C_b',
#  'SNL_18650_NMC_15C_0-100_0.5-2C_b',
#  'SNL_18650_LFP_35C_0-100_0.5-1C_d',
#  'SNL_18650_NCA_35C_0-100_0.5-1C_a',
#  'SNL_18650_LFP_35C_0-100_0.5-2C_b',
#  'SNL_18650_NMC_25C_0-100_0.5-1C_c',
#  'SNL_18650_NMC_25C_0-100_0.5-3C_a',
#  'SNL_18650_NCA_35C_0-100_0.5-1C_d',
#  'SNL_18650_NMC_25C_0-100_0.5-1C_d',
#  'SNL_18650_LFP_25C_0-100_0.5-3C_a',
#  'SNL_18650_NCA_15C_0-100_0.5-2C_a',
#  'SNL_18650_NMC_25C_0-100_0.5-2C_a',
#  'SNL_18650_NCA_35C_0-100_0.5-1C_c',
#  'SNL_18650_NCA_15C_0-100_0.5-1C_b',
#  'SNL_18650_NCA_35C_0-100_0.5-2C_a',
#  'SNL_18650_LFP_25C_0-100_0.5-3C_d',
#  'SNL_18650_NCA_15C_0-100_0.5-1C_a',
#  'SNL_18650_NMC_35C_0-100_0.5-2C_a',
#  'SNL_18650_NMC_15C_0-100_0.5-2C_a',
#  'SNL_18650_NCA_25C_20-80_0.5-0.5C_c',
#  'SNL_18650_NMC_25C_0-100_0.5-2C_b',
#  'SNL_18650_NMC_25C_0-100_0.5-0.5C_b',
#  'SNL_18650_NMC_35C_0-100_0.5-1C_a',
#  'SNL_18650_LFP_35C_0-100_0.5-1C_b',
#  'MICH_BLForm2_pouch_NMC_45C_0-100_1-1C_b',
#  'MICH_BLForm1_pouch_NMC_45C_0-100_1-1C_a',
#  'MICH_MCForm32_pouch_NMC_45C_0-100_1-1C_b',
#  'MICH_MCForm27_pouch_NMC_25C_0-100_1-1C_g',
#  'MICH_MCForm22_pouch_NMC_25C_0-100_1-1C_b',
#  'MICH_MCForm36_pouch_NMC_45C_0-100_1-1C_f',
#  'MICH_MCForm29_pouch_NMC_25C_0-100_1-1C_i',
#  'MICH_MCForm39_pouch_NMC_45C_0-100_1-1C_i',
#  'MICH_BLForm5_pouch_NMC_45C_0-100_1-1C_e',
#  'MICH_BLForm16_pouch_NMC_25C_0-100_1-1C_f',
#  'MICH_MCForm30_pouch_NMC_25C_0-100_1-1C_j',
#  'MICH_BLForm14_pouch_NMC_25C_0-100_1-1C_d',
#  'MICH_MCForm38_pouch_NMC_45C_0-100_1-1C_h',
#  'MICH_BLForm8_pouch_NMC_45C_0-100_1-1C_h',
#  'MICH_BLForm17_pouch_NMC_25C_0-100_1-1C_g',
#  'MICH_MCForm23_pouch_NMC_25C_0-100_1-1C_c',
#  'MICH_BLForm18_pouch_NMC_25C_0-100_1-1C_h',
#  'MICH_BLForm10_pouch_NMC_25C_0-100_1-1C_j',
#  'MICH_MCForm35_pouch_NMC_45C_0-100_1-1C_e',
#  'MICH_MCForm25_pouch_NMC_25C_0-100_1-1C_e',
#  'MICH_MCForm26_pouch_NMC_25C_0-100_1-1C_f',
#  'MICH_MCForm37_pouch_NMC_45C_0-100_1-1C_g',
#  'MICH_BLForm15_pouch_NMC_25C_0-100_1-1C_e',
#  'MICH_MCForm31_pouch_NMC_45C_0-100_1-1C_a',
#  'MICH_11C_pouch_NMC_-5C_0-100_0.2-1.5C',
#  'MICH_02C_pouch_NMC_-5C_0-100_0.2-0.2C',
#  'MICH_18H_pouch_NMC_45C_50-100_0.2-1.5C',
#  'MICH_04R_pouch_NMC_25C_0-100_1.5-1.5C',
#  'MICH_03H_pouch_NMC_45C_0-100_0.2-0.2C',
#  'MICH_08C_pouch_NMC_-5C_0-100_2-2C',
#  'MICH_17C_pouch_NMC_-5C_50-100_0.2-1.5C',
#  'MICH_10R_pouch_NMC_25C_0-100_0.2-1.5C',
#  'MICH_15H_pouch_NMC_45C_50-100_0.2-0.2C',
#  'MICH_13R_pouch_NMC_25C_50-100_0.2-0.2C',
#  'MICH_14C_pouch_NMC_-5C_50-100_0.2-0.2C',
#  'MICH_12H_pouch_NMC_45C_0-100_0.2-1.5C',
#  'XJTU_2C_battery-6',
#  'XJTU_2C_battery-2',
#  'XJTU_3C_battery-2',
#  'XJTU_3C_battery-3',
#  'XJTU_3C_battery-10',
#  'XJTU_3C_battery-13',
#  'XJTU_3C_battery-7',
#  'XJTU_3C_battery-15',
#  'XJTU_3C_battery-4',
#  'XJTU_3C_battery-5',
#  'XJTU_3C_battery-11',
#  'XJTU_3C_battery-6',
#  'XJTU_2C_battery-1',
#  'XJTU_2C_battery-8',
#  'XJTU_2C_battery-4']

# %% [markdown]
# ## Tokenize and embedding

# %%
def create_causal_mask(B, seq_len):
    '''
    return:
        casual mask: [B, L, L]. 0 indicates masked.
    '''
    # Create a lower triangular matrix of shape (seq_len, seq_len)
    mask = torch.tril(torch.ones(seq_len, seq_len))  # (L, L)
    mask = mask.unsqueeze(0).expand(B, -1, -1)
    return mask

# %%
# loader the tokenizer and model
# models--meta-llama--Llama-3.1-70B-Instruct
# /data/LLMs/models--meta-llama--Llama-3.1-70B-Instruct/snapshots/945c8663693130f8be2ee66210e062158b2a9693
# '/data/LLMs/models--meta-llama--Llama-3.1-8B-Instruct/snapshots/0e9e39f249a16976918f6564b8830bc894c89659'
LLM_path = '/data/LLMs/models--meta-llama--Llama-3.1-70B-Instruct/snapshots/945c8663693130f8be2ee66210e062158b2a9693'
llama_config = AutoConfig.from_pretrained(LLM_path)
language_model = AutoModel.from_pretrained(
            LLM_path,
            # 'huggyllama/llama-7b',
            trust_remote_code=True,
            local_files_only=True,
            config=llama_config,
            load_in_4bit=True
        )
tokenizer = AutoTokenizer.from_pretrained(
                LLM_path,
                # 'huggyllama/llama-7b',
                trust_remote_code=True,
                local_files_only=True, 
                pad_token='<|endoftext|>'
            )
tokenizer.padding_side = 'right' # set the padding side
# Out:
# The `load_in_4bit` and `load_in_8bit` arguments are deprecated and will be removed in the future versions. Please, pass a `BitsAndBytesConfig` object in `quantization_config` argument instead.
# `low_cpu_mem_usage` was None, now set to True since model is quantized.
# Loading checkpoint shards:   0%|          | 0/30 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# OutOfMemoryError                          Traceback (most recent call last)
# Cell In[4], line 7
#       5 LLM_path = '/data/LLMs/models--meta-llama--Llama-3.1-70B-Instruct/snapshots/945c8663693130f8be2ee66210e062158b2a9693'
#       6 llama_config = AutoConfig.from_pretrained(LLM_path)
# ----> 7 language_model = AutoModel.from_pretrained(
#       8             LLM_path,
#       9             # 'huggyllama/llama-7b',
#      10             trust_remote_code=True,
#      11             local_files_only=True,
#      12             config=llama_config,
#      13             load_in_4bit=True
#      14         )
#      15 tokenizer = AutoTokenizer.from_pretrained(
#      16                 LLM_path,
#      17                 # 'huggyllama/llama-7b',
#    (...)
#      20                 pad_token='<|endoftext|>'
#      21             )
#      22 tokenizer.padding_side = 'right' # set the padding side
#
# File ~/envs/llmpy311/lib/python3.11/site-packages/transformers/models/auto/auto_factory.py:564, in _BaseAutoModelClass.from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     562 elif type(config) in cls._model_mapping.keys():
#     563     model_class = _get_model_class(config, cls._model_mapping)
# --> 564     return model_class.from_pretrained(
#     565         pretrained_model_name_or_path, *model_args, config=config, **hub_kwargs, **kwargs
#     566     )
#     567 raise ValueError(
#     568     f"Unrecognized configuration class {config.__class__} for this kind of AutoModel: {cls.__name__}.\n"
#     569     f"Model type should be one of {', '.join(c.__name__ for c in cls._model_mapping.keys())}."
#     570 )
#
# File ~/envs/llmpy311/lib/python3.11/site-packages/transformers/modeling_utils.py:3960, in PreTrainedModel.from_pretrained(cls, pretrained_model_name_or_path, config, cache_dir, ignore_mismatched_sizes, force_download, local_files_only, token, revision, use_safetensors, *model_args, **kwargs)
#    3950     if dtype_orig is not None:
#    3951         torch.set_default_dtype(dtype_orig)
#    3953     (
#    3954         model,
#    3955         missing_keys,
#    3956         unexpected_keys,
#    3957         mismatched_keys,
#    3958         offload_index,
#    3959         error_msgs,
# -> 3960     ) = cls._load_pretrained_model(
#    3961         model,
#    3962         state_dict,
#    3963         loaded_state_dict_keys,  # XXX: rename?
#    3964         resolved_archive_file,
#    3965         pretrained_model_name_or_path,
#    3966         ignore_mismatched_sizes=ignore_mismatched_sizes,
#    3967         sharded_metadata=sharded_metadata,
#    3968         _fast_init=_fast_init,
#    3969         low_cpu_mem_usage=low_cpu_mem_usage,
#    3970         device_map=device_map,
#    3971         offload_folder=offload_folder,
#    3972         offload_state_dict=offload_state_dict,
#    3973         dtype=torch_dtype,
#    3974         hf_quantizer=hf_quantizer,
#    3975         keep_in_fp32_modules=keep_in_fp32_modules,
#    3976         gguf_path=gguf_path,
#    3977     )
#    3979 # make sure token embedding weights are still tied if needed
#    3980 model.tie_weights()
#
# File ~/envs/llmpy311/lib/python3.11/site-packages/transformers/modeling_utils.py:4434, in PreTrainedModel._load_pretrained_model(cls, model, state_dict, loaded_keys, resolved_archive_file, pretrained_model_name_or_path, ignore_mismatched_sizes, sharded_metadata, _fast_init, low_cpu_mem_usage, device_map, offload_folder, offload_state_dict, dtype, hf_quantizer, keep_in_fp32_modules, gguf_path)
#    4430                 set_module_tensor_to_device(
#    4431                     model_to_load, key, "cpu", torch.empty(*param.size(), dtype=dtype)
#    4432                 )
#    4433     else:
# -> 4434         new_error_msgs, offload_index, state_dict_index = _load_state_dict_into_meta_model(
#    4435             model_to_load,
#    4436             state_dict,
#    4437             loaded_keys,
#    4438             start_prefix,
#    4439             expected_keys,
#    4440             device_map=device_map,
#    4441             offload_folder=offload_folder,
#    4442             offload_index=offload_index,
#    4443             state_dict_folder=state_dict_folder,
#    4444             state_dict_index=state_dict_index,
#    4445             dtype=dtype,
#    4446             hf_quantizer=hf_quantizer,
#    4447             is_safetensors=is_safetensors,
#    4448             keep_in_fp32_modules=keep_in_fp32_modules,
#    4449             unexpected_keys=unexpected_keys,
#    4450         )
#    4451         error_msgs += new_error_msgs
#    4452 else:
#    4453     # Sharded checkpoint or whole but low_cpu_mem_usage==True
#
# File ~/envs/llmpy311/lib/python3.11/site-packages/transformers/modeling_utils.py:963, in _load_state_dict_into_meta_model(model, state_dict, loaded_state_dict_keys, start_prefix, expected_keys, device_map, offload_folder, offload_index, state_dict_folder, state_dict_index, dtype, hf_quantizer, is_safetensors, keep_in_fp32_modules, unexpected_keys, pretrained_model_name_or_path)
#     961     set_module_tensor_to_device(model, param_name, param_device, **set_module_kwargs)
#     962 else:
# --> 963     hf_quantizer.create_quantized_param(model, param, param_name, param_device, state_dict, unexpected_keys)
#     964     # For quantized modules with FSDP/DeepSpeed Stage 3, we need to quantize the parameter on the GPU
#     965     # and then cast it to CPU to avoid excessive memory usage on each GPU
#     966     # in comparison to the sharded model across GPUs.
#     967     if is_fsdp_enabled() or is_deepspeed_zero3_enabled():
#
# File ~/envs/llmpy311/lib/python3.11/site-packages/transformers/quantizers/quantizer_bnb_4bit.py:217, in Bnb4BitHfQuantizer.create_quantized_param(self, model, param_value, param_name, target_device, state_dict, unexpected_keys)
#     214         new_value = new_value.T
#     216     kwargs = old_value.__dict__
# --> 217     new_value = bnb.nn.Params4bit(new_value, requires_grad=False, **kwargs).to(target_device)
#     219 module._parameters[tensor_name] = new_value
#
# File ~/envs/llmpy311/lib/python3.11/site-packages/bitsandbytes/nn/modules.py:332, in Params4bit.to(self, *args, **kwargs)
#     329 device, dtype, non_blocking, convert_to_format = torch._C._nn._parse_to(*args, **kwargs)
#     331 if device is not None and device.type == "cuda" and not self.bnb_quantized:
# --> 332     return self._quantize(device)
#     333 else:
#     334     if self.quant_state is not None:
#
# File ~/envs/llmpy311/lib/python3.11/site-packages/bitsandbytes/nn/modules.py:297, in Params4bit._quantize(self, device)
#     295 def _quantize(self, device):
#     296     w = self.data.contiguous().to(device)
# --> 297     w_4bit, quant_state = bnb.functional.quantize_4bit(
#     298         w,
#     299         blocksize=self.blocksize,
#     300         compress_statistics=self.compress_statistics,
#     301         quant_type=self.quant_type,
#     302         quant_storage=self.quant_storage,
#     303     )
#     304     self.data = w_4bit
#     305     self.quant_state = quant_state
#
# File ~/envs/llmpy311/lib/python3.11/site-packages/bitsandbytes/functional.py:1173, in quantize_4bit(A, absmax, out, blocksize, compress_statistics, quant_type, quant_storage)
#    1171 if out is None:
#    1172     mod = dtype2bytes[quant_storage] * 2
# -> 1173     out = torch.zeros(((n + 1) // mod, 1), dtype=quant_storage, device=A.device)
#    1175 assert blocksize in [4096, 2048, 1024, 512, 256, 128, 64]
#    1177 prev_device = pre_call(A.device)
#
# OutOfMemoryError: CUDA out of memory. Tried to allocate 112.00 MiB. GPU 0 has a total capacity of 23.65 GiB of which 100.56 MiB is free. Process 2290406 has 6.20 GiB memory in use. Process 2290574 has 6.19 GiB memory in use. Including non-PyTorch memory, this process has 11.14 GiB memory in use. Of the allocated memory 10.68 GiB is allocated by PyTorch, and 30.36 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)

# %%
def read_cell_data_according_to_prefix(file_name, root_path):
    prefix = file_name.split('_')[0]
    if prefix == 'MICH':
        with open(f'{root_path}/total_MICH_labels.json') as f:
            life_labels = json.load(f)
    elif prefix.startswith('Tongji'):
        with open(f'{root_path}/Tongji_labels.json') as f:
            life_labels = json.load(f)
    else:
        with open(f'{root_path}/{prefix}_labels.json') as f:
            life_labels = json.load(f)
            
    if file_name in life_labels:
        eol = life_labels[file_name]
    else:
        eol = None

    return eol

def get_features_from_cellNames(cell_names):
    cellName_prompt = {}
    total_labels = []
    for cell_name in cell_names:
        bg_prompt = (
                    f"Task description: You are an expert in predicting battery cycle life. " 
                    f"The cycle life is the number of cycles until the battery's discharge capacity reaches 80% of its nominal capacity. "
                    f"The discharge capacity is calculated under the described operating condition. "
                    f"Please directly output the cycle life of the battery based on the provided data. "
                    )
        helper = Mapping_helper(prompt_type='PROTOCOL', cell_name=cell_name)
        tmp_prompt = bg_prompt + helper.do_mapping()
        eol = read_cell_data_according_to_prefix(cell_name+'.pkl', '/data/trf/python_works/BatteryLife/dataset')
        if eol is None:
            print(cell_name+'.pkl')
            continue
        total_labels.append(eol)
        # Llama-instruct
        messages = [
            {"role": "system", "content": "You are a helpful assistant."},
            {"role": "user", "content": tmp_prompt}
        ]

        tmp_prompt = tokenizer.apply_chat_template(
            messages,
            tokenize=False,
            add_generation_prompt=False
        )

        res = tokenizer(tmp_prompt, return_tensors="pt")
        input_ids, attention_mask = res['input_ids'][:,1:], res['attention_mask'][:,1:]
        llama_enc_out = language_model.get_input_embeddings()(input_ids) # [1, L', d_llm]
        
        cache_position = torch.arange(0, llama_enc_out.shape[1], device=llama_enc_out.device)
        position_ids = cache_position.unsqueeze(0)
        DLP_attention_mask = attention_mask.unsqueeze(1) # [B, 1, L]
        DLP_attention_mask = DLP_attention_mask.expand(-1, DLP_attention_mask.shape[-1], -1) # [B, L, L]
        DLP_attention_mask = DLP_attention_mask.unsqueeze(1) # [B, 1, L, L]
        
        casual_mask = create_causal_mask(1, llama_enc_out.shape[1])
        casual_mask = casual_mask.unsqueeze(1) # [B, 1, L, L]

        DLP_attention_mask = torch.where(casual_mask.to(DLP_attention_mask.device)==1, DLP_attention_mask, torch.zeros_like(DLP_attention_mask))
        DLP_attention_mask = DLP_attention_mask==1 # set True to allow attention to attend to

        hidden_states = llama_enc_out
        for i, layer in enumerate(language_model.layers):
            res = layer(hidden_states=hidden_states, position_ids=position_ids, attention_mask=DLP_attention_mask, cache_position=cache_position)
            hidden_states = res[0]

        features = hidden_states[:,-1,:].detach().cpu().numpy().reshape(1, -1)
        
        cellName_prompt[cell_name] = features
    return cellName_prompt, total_labels

cellName_prompt, total_labels = get_features_from_cellNames(cell_names)

# get the features from validation and testing sets
val_cell_names = [i.split('.pkl')[0] for i in split_recorder.MIX_large_val_files]
test_cell_names = [i.split('.pkl')[0] for i in split_recorder.MIX_large_test_files]
val_cellName_prompt, val_total_labels = get_features_from_cellNames(val_cell_names)
test_cellName_prompt, test_total_labels = get_features_from_cellNames(test_cell_names)
# Out:
# /home/trf/envs/llmpy311/lib/python3.11/site-packages/bitsandbytes/nn/modules.py:435: UserWarning: Input type into Linear4bit is torch.float16, but bnb_4bit_compute_dtype=torch.float32 (default). This will lead to slow inference or training speed.
#   warnings.warn(
# The attention layers in this model are transitioning from computing the RoPE embeddings internally through `position_ids` (2D tensor with the indexes of the tokens), to using externally computed `position_embeddings` (Tuple of tensors, containing cos and sin). In v4.45 `position_ids` will be removed and `position_embeddings` will be mandatory.
# MICH_18H_pouch_NMC_45C_50-100_0.2-1.5C.pkl
# MICH_17C_pouch_NMC_-5C_50-100_0.2-1.5C.pkl
# MICH_15H_pouch_NMC_45C_50-100_0.2-0.2C.pkl
# MICH_13R_pouch_NMC_25C_50-100_0.2-0.2C.pkl
# MICH_14C_pouch_NMC_-5C_50-100_0.2-0.2C.pkl
# MICH_16R_pouch_NMC_25C_50-100_0.2-1.5C.pkl

# %% [markdown]
# ## Visualize the embeddings

# %%
from sklearn.manifold import TSNE
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
total_features = []
names = []
for name, feature in cellName_prompt.items():
    name = name.split('_')[0]
    names.append(name)
    total_features.append(feature)


val_total_features = []
val_names = []
for name, feature in val_cellName_prompt.items():
    name = name.split('_')[0]
    val_names.append(name)
    val_total_features.append(feature)

test_total_features = []
test_names = []
for name, feature in test_cellName_prompt.items():
    name = name.split('_')[0]
    test_names.append(name)
    test_total_features.append(feature)

concated_features = np.concatenate(total_features+val_total_features+test_total_features, axis=0)

train_split = len(cellName_prompt)
val_split = train_split + len(val_cellName_prompt)

total_features = np.concatenate(total_features, axis=0)
# Perform TSNE to project the features to 2D
tsne = TSNE(n_components=2, random_state=42)
X_embedded = tsne.fit_transform(concated_features)

# Visualize the TSNE projection
plt.figure(figsize=(5, 4))
plt.scatter(X_embedded[:train_split, 0], X_embedded[:train_split, 1], c='blue', alpha=0.7, edgecolors='k', s=50)
plt.scatter(X_embedded[train_split:val_split, 0], X_embedded[train_split:val_split, 1], c='red', alpha=0.7, edgecolors='k', s=50)
plt.scatter(X_embedded[val_split:, 0], X_embedded[val_split:, 1], c='green', alpha=0.7, edgecolors='k', s=50)
# # Add names to points (optional, if the dataset is small)
# for i, name in enumerate(names):
#     plt.text(X_embedded[i, 0] + 0.2, X_embedded[i, 1], name, fontsize=8)

plt.title("TSNE Visualization of Features")
plt.xlabel("TSNE Dimension 1")
plt.ylabel("TSNE Dimension 2")
plt.grid(True)
plt.savefig('./figures/t-SNE_train-val-test.jpg', dpi=600)
plt.show()

# %%
import matplotlib.cm as cm
import matplotlib.pyplot as plt
import numpy as np

from sklearn.cluster import KMeans
from sklearn.datasets import make_blobs
from sklearn.metrics import silhouette_samples, silhouette_score


X = total_features
range_n_clusters = list(range(2,30))
total_scores = []
for n_clusters in range_n_clusters:


    # Initialize the clusterer with n_clusters value and a random generator
    # seed of 10 for reproducibility.
    clusterer = KMeans(n_clusters=n_clusters, random_state=10)
    cluster_labels = clusterer.fit_predict(X)

    # The silhouette_score gives the average value for all the samples.
    # This gives a perspective into the density and separation of the formed
    # clusters
    silhouette_avg = silhouette_score(X, cluster_labels)
    print(
        "For n_clusters =",
        n_clusters,
        "The average silhouette_score is :",
        silhouette_avg,
    )
    total_scores.append(silhouette_avg)

fig = plt.figure(figsize=(4, 4))
plt.plot(range_n_clusters, total_scores, marker='o', markerfacecolor='white')
plt.xlabel('The number of clusters')
plt.ylabel('The average silhouette_score')
plt.show()

n_cluster_scores = dict(zip(range_n_clusters, total_scores))
n_cluster_scores = sorted(n_cluster_scores.items(), key= lambda x:x[1], reverse=True)
n_cluster_scores
# Out:
# For n_clusters = 2 The average silhouette_score is : 0.32390031921912005
# For n_clusters = 3 The average silhouette_score is : 0.38363909356551024
# For n_clusters = 4 The average silhouette_score is : 0.35010307245971173
# For n_clusters = 5 The average silhouette_score is : 0.3617749015034399
# For n_clusters = 6 The average silhouette_score is : 0.417633390817176
# For n_clusters = 7 The average silhouette_score is : 0.41041495022391744
# For n_clusters = 8 The average silhouette_score is : 0.4161633304847335
# For n_clusters = 9 The average silhouette_score is : 0.4755993556178419
# For n_clusters = 10 The average silhouette_score is : 0.4743831398754116
# For n_clusters = 11 The average silhouette_score is : 0.4775658600757484
# For n_clusters = 12 The average silhouette_score is : 0.5082557556757136
# For n_clusters = 13 The average silhouette_score is : 0.5292731066630134
# For n_clusters = 14 The average silhouette_score is : 0.5383734660342123
# For n_clusters = 15 The average silhouette_score is : 0.5630373746110602
# For n_clusters = 16 The average silhouette_score is : 0.5495012806168588
# For n_clusters = 17 The average silhouette_score is : 0.5641507964077666
# For n_clusters = 18 The average silhouette_score is : 0.5778248730183329
# For n_clusters = 19 The average silhouette_score is : 0.5932955877937904
# For n_clusters = 20 The average silhouette_score is : 0.58299467922691
# For n_clusters = 21 The average silhouette_score is : 0.5617536067002482
# For n_clusters = 22 The average silhouette_score is : 0.5664831943332789
# For n_clusters = 23 The average silhouette_score is : 0.5663701685777781
# For n_clusters = 24 The average silhouette_score is : 0.5340381962222522
# For n_clusters = 25 The average silhouette_score is : 0.544654028814461
# For n_clusters = 26 The average silhouette_score is : 0.5589678068129457
# For n_clusters = 27 The average silhouette_score is : 0.5599527111969063
# For n_clusters = 28 The average silhouette_score is : 0.5778168127626101
# For n_clusters = 29 The average silhouette_score is : 0.5850320696373785
# [(19, np.float64(0.5932955877937904)),
#  (29, np.float64(0.5850320696373785)),
#  (20, np.float64(0.58299467922691)),
#  (18, np.float64(0.5778248730183329)),
#  (28, np.float64(0.5778168127626101)),
#  (22, np.float64(0.5664831943332789)),
#  (23, np.float64(0.5663701685777781)),
#  (17, np.float64(0.5641507964077666)),
#  (15, np.float64(0.5630373746110602)),
#  (21, np.float64(0.5617536067002482)),
#  (27, np.float64(0.5599527111969063)),
#  (26, np.float64(0.5589678068129457)),
#  (16, np.float64(0.5495012806168588)),
#  (25, np.float64(0.544654028814461)),
#  (14, np.float64(0.5383734660342123)),
#  (24, np.float64(0.5340381962222522)),
#  (13, np.float64(0.5292731066630134)),
#  (12, np.float64(0.5082557556757136)),
#  (11, np.float64(0.4775658600757484)),
#  (9, np.float64(0.4755993556178419)),
#  (10, np.float64(0.4743831398754116)),
#  (6, np.float64(0.417633390817176)),
#  (8, np.float64(0.4161633304847335)),
#  (7, np.float64(0.41041495022391744)),
#  (3, np.float64(0.38363909356551024)),
#  (5, np.float64(0.3617749015034399)),
#  (4, np.float64(0.35010307245971173)),
#  (2, np.float64(0.32390031921912005))]

# %% [markdown]
# ## Cluster and visualize
# We cluster the samples using K-Means and visualize the clusters

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

total_labels = np.array(total_labels)
tmp_total_features = total_features
tmp_total_labels = total_labels
norm = mpl.colors.Normalize(vmin=min(tmp_total_labels), vmax=max(tmp_total_labels))
tmp_total_labels = tmp_total_labels.reshape(-1, 1)
tmp_total_labels = scaler.fit_transform(tmp_total_labels).reshape(-1)

# Use the K that has the highest score
set_n_clusters = n_cluster_scores[0][0]
set_n_clusters = 5

print(f'Best K is {set_n_clusters}')
k_means = KMeans(n_clusters=n_cluster_scores[0][0], random_state=5)
cluster_labels = k_means.fit_predict(tmp_total_features)
cluster_centers = k_means.cluster_centers_ # [set_n_clusters, d_llm]

# Perform t-SNE on the embeddings (total_features)
tsne = TSNE(n_components=2, random_state=42, perplexity=5)  # Reduce to 2D for visualization
tsne_results = tsne.fit_transform(tmp_total_features)
dataset_names = names

plt.figure(figsize=(12, 8))
# Define a list of different shapes for the clusters
dataset_shapes = ['o', 's', '^', 'D', 'v', 'p', '*', 'X', '+', '3', '<', '>', '4', 'H']
unique_datasets = list(set(dataset_names))
dataset_shape_map = dict(zip(unique_datasets, dataset_shapes))

# Define a list of different colors for the datasets
# We'll use a set to get unique dataset names, and then assign a color to each dataset
unique_cluster_labels = list(set(cluster_labels))
colormap =  mpl.colormaps['coolwarm']
# # Map each unique dataset name to a color
# cluster_color_map = {name: colors[i] for i, name in enumerate(unique_cluster_labels)}

# Plot each point with its corresponding cluster label and dataset shape
appear_datasetNames = []
for i in range(len(tmp_total_features)):
    if dataset_names[i] not in appear_datasetNames:
        plt.scatter(tsne_results[i, 0], tsne_results[i, 1],
                    c=[colormap(tmp_total_labels[i])],  # Color by cluster label
                    marker=dataset_shape_map[dataset_names[i]],  # Shape by dataset name
                     s=100, edgecolor='k', label=dataset_names[i])
    else:
        plt.scatter(tsne_results[i, 0], tsne_results[i, 1],
                    c=[colormap(tmp_total_labels[i])],  # Color by cluster label
                    marker=dataset_shape_map[dataset_names[i]],  # Shape by dataset name
                    s=100, edgecolor='k')
    appear_datasetNames.append(dataset_names[i])

# Add labels and title
plt.title("t-SNE Visualization of K-Means Clusters with Dataset Shapes", fontsize=16)
plt.xlabel("t-SNE Component 1", fontsize=14)
plt.ylabel("t-SNE Component 2", fontsize=14)

# Custom legend for cluster shapes only (no color distinction)
legend_shapes = [Line2D([0], [0], marker=shape, color='w', markerfacecolor='k', markersize=15) for shape in dataset_shapes]
# plt.legend(dataset_shapes, unique_datasets, title="Datasets", loc='upper right')
cb = fig.colorbar(mpl.cm.ScalarMappable(norm=norm, cmap=colormap),label='Measured Cycle Life',ax=plt.gca())
plt.legend()
plt.xlim(-300, 250)
plt.ylim(-210, 300)
fig.tight_layout()
plt.savefig('./figures/t-SNE_clustering.jpg', dpi=600)
plt.show()


# plt.figure(figsize=(10, 8))
# # Define a list of different shapes for the clusters
# dataset_shapes = ['o', 's', '^', 'D', 'v', 'p', '*', 'X', '+', '3', '<', '>', '4', 'H']
# unique_datasets = list(set(dataset_names))
# dataset_shape_map = dict(zip(unique_datasets, dataset_shapes))

# # Define a list of different colors for the datasets
# # We'll use a set to get unique dataset names, and then assign a color to each dataset
# unique_cluster_labels = list(set(cluster_labels))
# colors = sns.color_palette("Set1", len(unique_cluster_labels))

# # Map each unique dataset name to a color
# cluster_color_map = {name: colors[i] for i, name in enumerate(unique_cluster_labels)}

# # Plot each point with its corresponding cluster label and dataset shape
# appear_datasetNames = []
# for i in range(len(total_features)):
#     if dataset_names[i] not in appear_datasetNames:
#         plt.scatter(tsne_results[i, 0], tsne_results[i, 1],
#                     c=[cluster_color_map[cluster_labels[i]]],  # Color by cluster label
#                     marker=dataset_shape_map[dataset_names[i]],  # Shape by dataset name
#                     cmap='Set1', s=100, edgecolor='k', label=dataset_names[i])
#     else:
#         plt.scatter(tsne_results[i, 0], tsne_results[i, 1],
#                     c=[cluster_color_map[cluster_labels[i]]],  # Color by cluster label
#                     marker=dataset_shape_map[dataset_names[i]],  # Shape by dataset name
#                     cmap='Set1', s=100, edgecolor='k')
#     appear_datasetNames.append(dataset_names[i])

# # Add labels and title
# plt.title("t-SNE Visualization of K-Means Clusters with Dataset Shapes", fontsize=16)
# plt.xlabel("t-SNE Component 1", fontsize=14)
# plt.ylabel("t-SNE Component 2", fontsize=14)

# # Custom legend for cluster shapes only (no color distinction)
# legend_shapes = [Line2D([0], [0], marker=shape, color='w', markerfacecolor='k', markersize=15) for shape in dataset_shapes]
# # plt.legend(dataset_shapes, unique_datasets, title="Datasets", loc='upper right')
# plt.savefig('./figures/t-SNE_clustering.jpg', dpi=600)
# plt.show()
# Out:
# Best K is 5
# /tmp/ipykernel_1780275/471068494.py:42: UserWarning: You passed a edgecolor/edgecolors ('k') for an unfilled marker ('4').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   plt.scatter(tsne_results[i, 0], tsne_results[i, 1],
# /tmp/ipykernel_1780275/471068494.py:47: UserWarning: You passed a edgecolor/edgecolors ('k') for an unfilled marker ('4').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   plt.scatter(tsne_results[i, 0], tsne_results[i, 1],
# /tmp/ipykernel_1780275/471068494.py:42: UserWarning: You passed a edgecolor/edgecolors ('k') for an unfilled marker ('3').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   plt.scatter(tsne_results[i, 0], tsne_results[i, 1],
# /tmp/ipykernel_1780275/471068494.py:47: UserWarning: You passed a edgecolor/edgecolors ('k') for an unfilled marker ('3').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   plt.scatter(tsne_results[i, 0], tsne_results[i, 1],
# /tmp/ipykernel_1780275/471068494.py:42: UserWarning: You passed a edgecolor/edgecolors ('k') for an unfilled marker ('+').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   plt.scatter(tsne_results[i, 0], tsne_results[i, 1],
# /tmp/ipykernel_1780275/471068494.py:47: UserWarning: You passed a edgecolor/edgecolors ('k') for an unfilled marker ('+').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   plt.scatter(tsne_results[i, 0], tsne_results[i, 1],

# %% [markdown]
# ## Save the results

# %%
## Export the clustering results
cluster_labels = [int(i) for i in cluster_labels]
cellNames_ClusterLabels = dict(zip(list(cellName_prompt.keys()), cluster_labels))
print(cell_names)
index_clusterCenters = {}
for i in range(set_n_clusters):
    index_clusterCenters[i] = cluster_centers[i]

print(index_clusterCenters)
# Out:
# ['UL-PUR_N10-NA7_18650_NCA_23C_0-100_0.5-0.5C_g', 'UL-PUR_N15-NA10_18650_NCA_23C_0-100_0.5-0.5C_j', 'RWTH_016', 'RWTH_045', 'RWTH_009', 'RWTH_039', 'RWTH_046', 'RWTH_019', 'RWTH_037', 'RWTH_013', 'RWTH_003', 'RWTH_044', 'RWTH_026', 'RWTH_006', 'RWTH_031', 'RWTH_036', 'RWTH_048', 'RWTH_033', 'RWTH_021', 'RWTH_012', 'RWTH_034', 'RWTH_018', 'RWTH_022', 'RWTH_030', 'RWTH_028', 'RWTH_011', 'RWTH_040', 'RWTH_041', 'RWTH_042', 'RWTH_025', 'RWTH_047', 'RWTH_004', 'HUST_1-6', 'HUST_2-2', 'HUST_1-3', 'HUST_6-3', 'HUST_1-2', 'HUST_3-7', 'HUST_3-2', 'HUST_10-6', 'HUST_3-6', 'HUST_5-1', 'HUST_10-5', 'HUST_6-2', 'HUST_6-1', 'HUST_8-1', 'HUST_10-7', 'HUST_1-4', 'HUST_5-4', 'HUST_1-5', 'HUST_6-6', 'HUST_5-6', 'HUST_6-4', 'HUST_9-2', 'HUST_10-4', 'HUST_5-3', 'HUST_7-7', 'HUST_3-1', 'HUST_4-1', 'HUST_4-4', 'HUST_4-6', 'HUST_8-8', 'HUST_2-4', 'HUST_9-8', 'HUST_9-5', 'HUST_3-3', 'HUST_1-7', 'HUST_4-5', 'HUST_9-6', 'HUST_1-1', 'HUST_4-3', 'HUST_2-5', 'HUST_4-7', 'HUST_7-2', 'HUST_8-4', 'HUST_3-5', 'HUST_2-6', 'HUST_8-6', 'HUST_7-5', 'MATR_b1c5', 'MATR_b3c6', 'MATR_b1c7', 'MATR_b4c18', 'MATR_b3c44', 'MATR_b3c18', 'MATR_b2c12', 'MATR_b2c26', 'MATR_b4c26', 'MATR_b3c40', 'MATR_b1c9', 'MATR_b2c18', 'MATR_b3c17', 'MATR_b3c21', 'MATR_b2c6', 'MATR_b3c45', 'MATR_b1c23', 'MATR_b2c4', 'MATR_b1c35', 'MATR_b1c19', 'MATR_b2c39', 'MATR_b3c26', 'MATR_b2c28', 'MATR_b2c33', 'MATR_b3c39', 'MATR_b2c29', 'MATR_b3c31', 'MATR_b4c42', 'MATR_b4c7', 'MATR_b2c38', 'MATR_b1c41', 'MATR_b3c33', 'MATR_b4c40', 'MATR_b1c17', 'MATR_b3c1', 'MATR_b4c10', 'MATR_b1c33', 'MATR_b2c10', 'MATR_b3c13', 'MATR_b4c37', 'MATR_b4c23', 'MATR_b4c15', 'MATR_b2c0', 'MATR_b2c19', 'MATR_b4c1', 'MATR_b3c8', 'MATR_b1c15', 'MATR_b4c24', 'MATR_b3c15', 'MATR_b1c3', 'MATR_b1c16', 'MATR_b3c3', 'MATR_b4c20', 'MATR_b4c30', 'MATR_b4c25', 'MATR_b4c9', 'MATR_b1c20', 'MATR_b3c14', 'MATR_b2c5', 'MATR_b3c22', 'MATR_b3c16', 'MATR_b4c43', 'MATR_b4c19', 'MATR_b2c31', 'MATR_b2c21', 'MATR_b4c12', 'MATR_b2c36', 'MATR_b1c21', 'MATR_b2c3', 'MATR_b2c37', 'MATR_b4c4', 'MATR_b2c44', 'MATR_b4c34', 'MATR_b4c29', 'MATR_b3c7', 'MATR_b4c21', 'MATR_b2c1', 'MATR_b1c31', 'MATR_b2c14', 'MATR_b1c26', 'MATR_b4c38', 'MATR_b1c42', 'MATR_b2c17', 'MATR_b3c28', 'MATR_b3c10', 'MATR_b3c36', 'MATR_b3c24', 'MATR_b1c6', 'MATR_b2c34', 'MATR_b3c9', 'MATR_b4c14', 'MATR_b2c24', 'MATR_b2c30', 'MATR_b3c4', 'MATR_b4c11', 'MATR_b2c41', 'MATR_b4c8', 'MATR_b3c25', 'MATR_b1c38', 'MATR_b3c27', 'MATR_b1c18', 'MATR_b2c32', 'Stanford_Nova_Regular_228', 'Stanford_Nova_Regular_203', 'Stanford_Nova_Regular_215', 'Stanford_Nova_Regular_225', 'Stanford_Nova_Regular_222', 'Stanford_Nova_Regular_226', 'Stanford_Nova_Regular_221', 'Stanford_Nova_Regular_211', 'Stanford_Nova_Regular_219', 'Stanford_Nova_Regular_229', 'Stanford_Nova_Regular_193', 'Stanford_Nova_Regular_200', 'Stanford_Nova_Regular_205', 'Stanford_Nova_Regular_230', 'Stanford_Nova_Regular_196', 'Stanford_Nova_Regular_216', 'Stanford_Nova_Regular_220', 'Stanford_Nova_Regular_201', 'Stanford_Nova_Regular_Ref_101', 'Stanford_Nova_Regular_192', 'Stanford_Nova_Regular_208', 'Stanford_Nova_Regular_Ref_102', 'Stanford_Nova_Regular_210', 'Stanford_Nova_Regular_212', 'Stanford_Nova_Regular_199', 'Tongji1_CY35-05_1-#2', 'Tongji1_CY45-05_1-#21', 'Tongji1_CY45-05_1-#28', 'Tongji2_CY45-05_1-#11', 'Tongji1_CY25-1_1-#5', 'Tongji1_CY25-1_1-#9', 'Tongji1_CY45-05_1-#19', 'Tongji3_CY25-05_4-#1', 'Tongji1_CY25-05_1-#2', 'Tongji3_CY25-05_2-#1', 'Tongji1_CY45-05_1-#5', 'Tongji1_CY45-05_1-#13', 'Tongji1_CY45-05_1-#11', 'Tongji1_CY35-05_1-#1', 'Tongji1_CY45-05_1-#17', 'Tongji2_CY25-05_1-#13', 'Tongji1_CY25-1_1-#6', 'Tongji2_CY45-05_1-#22', 'Tongji1_CY45-05_1-#27', 'Tongji2_CY45-05_1-#27', 'Tongji1_CY25-05_1-#17', 'Tongji2_CY45-05_1-#9', 'Tongji3_CY25-05_2-#2', 'Tongji1_CY45-05_1-#18', 'Tongji3_CY25-05_4-#2', 'Tongji1_CY45-05_1-#20', 'Tongji1_CY45-05_1-#1', 'Tongji2_CY45-05_1-#23', 'Tongji2_CY25-05_1-#5', 'Tongji2_CY45-05_1-#25', 'Tongji1_CY25-05_1-#4', 'Tongji1_CY25-05_1-#12', 'Tongji1_CY25-05_1-#16', 'Tongji1_CY25-05_1-#13', 'T ...
# {0: array([ 0.74552284,  0.47995418, -0.07564416, ..., -0.0878418 ,
#         0.19345985,  0.74754357]), 1: array([ 0.76899858,  0.45787464, -0.29671964, ...,  0.45015092,
#         0.01917614,  0.65988991]), 2: array([ 0.74352634,  0.36696699, -0.2146823 , ...,  0.48129568,
#        -0.05144279,  0.92461568]), 3: array([ 0.69631231,  0.65455264,  0.0720273 , ..., -0.10400391,
#         0.17427572,  0.64190383]), 4: array([ 0.46581055,  0.64466797, -0.11431396, ...,  0.13713867,
#         0.07455566,  0.56287109])}

# %%
## Export the domain-knowledge prompt embeddings of the samples
save_path = '/data/trf/python_works/BatteryLife/dataset/'
print(len(cell_names))
print(len(cluster_labels))
print(len(cellNames_ClusterLabels))
for key,value in cellNames_ClusterLabels.items():
    print(key, value)
with open(f'{save_path}index_clusterCenters.pkl', 'wb') as f:
    pickle.dump(index_clusterCenters, f)   

if not generate_for_transformer:
    if 'models--meta-llama--Llama-3.1-70B-Instruct' in LLM_path:
        with open(f'{save_path}cellNames_ClusterLabels_70b.json', 'w') as f:
            json.dump(cellNames_ClusterLabels, f)
        with open(f'{save_path}training_DKP_embed_70b.pkl', 'wb') as f:
            pickle.dump(cellName_prompt, f)

        with open(f'{save_path}validation_DKP_embed_70b.pkl', 'wb') as f:
            pickle.dump(val_cellName_prompt, f)

        with open(f'{save_path}testing_DKP_embed_70b.pkl', 'wb') as f:
            pickle.dump(test_cellName_prompt, f)
    else:
        with open(f'{save_path}cellNames_ClusterLabels.json', 'w') as f:
            json.dump(cellNames_ClusterLabels, f)
        with open(f'{save_path}training_DKP_embed.pkl', 'wb') as f:
            pickle.dump(cellName_prompt, f)

        with open(f'{save_path}validation_DKP_embed.pkl', 'wb') as f:
            pickle.dump(val_cellName_prompt, f)

        with open(f'{save_path}testing_DKP_embed.pkl', 'wb') as f:
            pickle.dump(test_cellName_prompt, f)
else:
    pass
# Out:
# 515
# 510
# 510
# UL-PUR_N10-NA7_18650_NCA_23C_0-100_0.5-0.5C_g 14
# UL-PUR_N15-NA10_18650_NCA_23C_0-100_0.5-0.5C_j 14
# RWTH_016 7
# RWTH_045 7
# RWTH_009 7
# RWTH_039 7
# RWTH_046 7
# RWTH_019 7
# RWTH_037 7
# RWTH_013 7
# RWTH_003 7
# RWTH_044 7
# RWTH_026 7
# RWTH_006 7
# RWTH_031 7
# RWTH_036 7
# RWTH_048 7
# RWTH_033 7
# RWTH_021 7
# RWTH_012 7
# RWTH_034 7
# RWTH_018 7
# RWTH_022 7
# RWTH_030 7
# RWTH_028 7
# RWTH_011 7
# RWTH_040 7
# RWTH_041 7
# RWTH_042 7
# RWTH_025 7
# RWTH_047 7
# RWTH_004 7
# HUST_1-6 3
# HUST_2-2 13
# HUST_1-3 13
# HUST_6-3 3
# HUST_1-2 13
# HUST_3-7 3
# HUST_3-2 13
# HUST_10-6 3
# HUST_3-6 3
# HUST_5-1 13
# HUST_10-5 13
# HUST_6-2 3
# HUST_6-1 18
# HUST_8-1 3
# HUST_10-7 3
# HUST_1-4 13
# HUST_5-4 3
# HUST_1-5 13
# HUST_6-6 3
# HUST_5-6 3
# HUST_6-4 18
# HUST_9-2 3
# HUST_10-4 3
# HUST_5-3 13
# HUST_7-7 13
# HUST_3-1 13
# HUST_4-1 18
# HUST_4-4 13
# HUST_4-6 13
# HUST_8-8 3
# HUST_2-4 13
# HUST_9-8 13
# HUST_9-5 3
# HUST_3-3 3
# HUST_1-7 3
# HUST_4-5 13
# HUST_9-6 13
# HUST_1-1 18
# HUST_4-3 13
# HUST_2-5 3
# HUST_4-7 3
# HUST_7-2 3
# HUST_8-4 13
# HUST_3-5 18
# HUST_2-6 13
# HUST_8-6 3
# HUST_7-5 13
# MATR_b1c5 14
# MATR_b3c6 0
# MATR_b1c7 14
# MATR_b4c18 6
# MATR_b3c44 0
# MATR_b3c18 0
# MATR_b2c12 0
# MATR_b2c26 14
# MATR_b4c26 6
# MATR_b3c40 0
# MATR_b1c9 0
# MATR_b2c18 0
# MATR_b3c17 0
# MATR_b3c21 0
# MATR_b2c6 0
# MATR_b3c45 14
# MATR_b1c23 0
# MATR_b2c4 0
# MATR_b1c35 0
# MATR_b1c19 0
# MATR_b2c39 0
# MATR_b3c26 0
# MATR_b2c28 0
# MATR_b2c33 0
# MATR_b3c39 0
# MATR_b2c29 0
# MATR_b3c31 0
# MATR_b4c42 6
# MATR_b4c7 6
# MATR_b2c38 0
# MATR_b1c41 0
# MATR_b3c33 0
# MATR_b4c40 6
# MATR_b1c17 0
# MATR_b3c1 0
# MATR_b4c10 6
# MATR_b1c33 0
# MATR_b2c10 0
# MATR_b3c13 0
# MATR_b4c37 6
# MATR_b4c23 6
# MATR_b4c15 6
# MATR_b2c0 0
# MATR_b2c19 0
# MATR_b4c1 6
# MATR_b3c8 0
# MATR_b1c15 0
# MATR_b4c24 6
# MATR_b3c15 0
# MATR_b1c3 14
# MATR_b1c16 0
# MATR_b3c3 0
# MATR_b4c20 6
# MATR_b4c30 6
# MATR_b4c25 6
# MATR_b4c9 6
# MATR_b1c20 14
# MATR_b3c14 0
# MATR_b2c5 0
# MATR_b3c22 0
# MATR_b3c16 14
# MATR_b4c43 6
# MATR_b4c19 6
# MATR_b2c31 0
# MATR_b2c21 0
# MATR_b4c12 6
# MATR_b2c36 0
# MATR_b1c21 14
# MATR_b2c3 0
# MATR_b2c37 0
# MATR_b4c4 6
# MATR_b2c44 0
# MATR_b4c34 6
# MATR_b4c29 6
# MATR_b3c7 14
# MATR_b4c21 6
# MATR_b2c1 0
# MATR_b1c31 0
# MATR_b2c14 0
# MATR_b1c26 0
# MATR_b4c38 6
# MATR_b1c42 0
# MATR_b2c17 0
# MATR_b3c28 0
# MATR_b3c10 0
# MATR_b3c36 0
# MATR_b3c24 0
# MATR_b1c6 14
# MATR_b2c34 0
# MATR_b3c9 0
# MATR_b4c14 6
# MATR_b2c24 14
# MATR_b2c30 0
# MATR_b3c4 0
# MATR_b4c11 6
# MATR_b2c41 0
# MATR_b4c8 6
# MATR_b3c25 0
# MATR_b1c38 0
# MATR_b3c27 0
# MATR_b1c18 0
# MATR_b2c32 0
# Stanford_Nova_Regular_228 4
# Stanford_Nova_Regular_203 4
# Stanford_Nova_Regular_215 4
# Stanford_Nova_Regular_225 4
# Stanford_Nova_Regular_222 4
# Stanford_Nova_Regular_226 4
# Stanford_Nova_Regular_221 4
# Stanford_Nova_Regular_211 4
# Stanford_Nova_Regular_219 4
# Stanford_Nova_Regular_229 4
# Stanford_Nova_Regular_193 4
# Stanford_Nova_Regular_200 4
# Stanford_Nova_Regular_205 4
# Stanford_Nova_Regular_230 4
# Stanford_Nova_Regular_196 4
# Stanford_Nova_Regular_216 4
# Stanford_Nova_Regular_220 4
# Stanford_Nova_Regular_201 4
# Stanford_Nova_Regular_Ref_101 4
# Stanford_Nova_Regular_192 4
# Stanford_Nova_Regular_208 4
# Stanford_Nova_Regular_Ref_102 4
# Stanford_Nova_Regular_210 4
# Stanford_Nova_Regular_212 4
# Stanford_Nova_Regular_199 4
# Tongji1_CY35-05_1-#2 8
# Tongji1_CY45-05_1-#21 8
# Tongji1_CY45-05_1-#28 8
# Tongji2_CY45-05_1-#11 8
# Tongji1_CY25-1_1-#5 8
# Tongji1_CY25-1_1-#9 8
# Tongji1_CY45-05_1-#19 8
# Tongji3_CY25-05_4-#1 8
# Tongji1_CY25-05_1-#2 8
# Tongji3_CY25-05_2-#1 8
# Tongji1_CY45-05_1-#5 8
# Tongji1_CY45-05_1-#13 8
# Tongji1_CY45-05_1-#11 8
# Tongji1_CY35-05_1-#1 8
# Tongji1_CY45-05_1-#17 8
# Tongji2_CY25-05_1-#13 8
# Tongji1_CY25-1_1-#6 8
# Tongji2_CY45-05_1-#22 8
# Tongji1_CY45-05_1-#27 8
# Tongji2_CY45-05_1-#27 8
# Tongji1_CY25-05_1-#17 8
# Tongji2_CY45-05_1-#9 8
# Tongji3_CY25-05_2-#2 8
# Tongji1_CY45-05_1-#18 8
# Tongji3_CY25-05_4-#2 8
# Tongji1_CY45-05_1-#20 8
# Tongji1_CY45-05_1-#1 8
# Tongji2_CY45-05_1-#23 8
# Tongji2_CY25-05_1-#5 8
# Tongji2_CY45-05_1-#25 8
# Tongji1_CY25-05_1-#4 8
# Tongji1_CY25-05_1-#12 8
# Tongji1_CY25-05_1-#16 8
# Tongji1_CY25-05_1-#13 8
# Tongji2_CY25-05_1-#17 8
# Tongji1_CY45-05_1-#7 8
# Tongji1_CY25-025_1-#5 8
# Tongji2_CY25-05_1-#12 8
# Tongji1_CY45-05_1-#6 8
# Tongji3_CY25-05_1-#2 8
# Tongji3_CY25-05_2-#3 8
# Tongji2_CY45-05_1-#16 8
# Tongji1_CY25-05_1-#15 8
# Tongji1_CY25-025_1-#3 8
# Tongji2_CY45-05_1-#7 8
# Tongji2_CY45-05_1-#20 8
# Tongji1_CY45-05_1-#23 8
# Tongji2_CY25-05_1-#15 8
# Tongji2_CY35-05_1-#4 8
# Tongji1_CY45-05_1-#12 8
# Tongji2_CY45-05_1-#15 8
# Tongji1_CY25-05_1-#5 8
# Tongji2_CY35-05_1-#3 8
# Tongji1_CY25-05_1-#14 8
# Tongji1_CY45-05_1-#26 8
# Tongji1_CY45-05_1-#22 8
# Tongji2_CY45-05_1-#24 8
# Tongji1_CY25-05_1-#18 8
# Tongji1_CY45-05_1-#9 8
# Tongji1_CY45-05_1-#24 8
# Tongji1_CY25-1_1-#4 8
# Tongji2_CY45-05_1-#26 8
# Tongji3_CY25-05_1-#3 8
# Tongji1_CY45-05_1-#15 8
# Tongji1_CY25-025_1-#2 8
# Tongji2_CY45-05_1-#14 8
# ISU-ILCC_G23C3 5
# ISU-ILCC_G64C4 14
# ISU-ILCC_G50C1 17
# ISU-ILCC_G36C2 5
# ISU-ILCC_G7C4 10
# ISU-ILCC_G16C2 5
# ISU-ILCC_G13C2 10
# ISU-ILCC_G29C3 2
# ISU-ILCC_G41C3 17
# ISU-ILCC_G39C4 5
# ISU-ILCC_G36C4 5
# ISU-ILCC_G28C3 17
# ISU-ILCC_G18C1 2
# ISU-ILCC_G58C1 10
# ISU-ILCC_G8C2 10
# ISU-ILCC_G16C3 5
# ISU-ILCC_G27C2 2
# ISU-ILCC_G22C1 5
# ISU-ILCC_G43C1 17
# ISU-ILCC_G53C2 5
# ISU-ILCC_G32C4 17
# ISU-ILCC_G44C3 2
# ISU-ILCC_G38C1 5
# ISU-ILCC_G61C3 17
# ISU-ILCC_G43C2 17
# ISU-ILCC_G20C2 5
# ISU-ILCC_G17C1 10
# ISU-ILCC_G33C4 17
# ISU-ILCC_G60C1 2
# ISU-ILCC_G27C3 2
# ISU-ILCC_G45C3 2
# ISU-ILCC_G18C4 2
# ISU-ILCC_G50C4 17
# ISU-ILCC_G1C1 2
# ISU-ILCC_G19C4 10
# ISU-ILCC_G49C4 17
# ISU-ILCC_G3C3 2
# ISU-ILCC_G19C2 2
# ISU-ILCC_G52C4 10
# ISU-ILCC_G31C1 2
# ISU-ILCC_G47C2 17
# ISU-ILCC_G43C4 17
# ISU-ILCC_G47C1 17
# ISU-ILCC_G40C2 17
# ISU-ILCC_G20C4 5
# ISU-ILCC_G6C2 10
# ISU-ILCC_G32C3 17
# ISU-ILCC_G41C4 17
# ISU-ILCC_G60C2 2
# ISU-ILCC_G64C3 14
# ISU-ILCC_G9C2 5
# ISU-ILCC_G49C3 17
# ISU-ILCC_G46C1 17
# ISU-ILCC_G30C1 17
# ISU-ILCC_G29C4 2
# ISU-ILCC_G50C2 17
# ISU-ILCC_G51C1 17
# ISU-ILCC_G55C2 17
# ISU-ILCC_G17C4 10
# ISU-ILCC_G50C3 17
# ISU-ILCC_G25C1 10
# ISU-ILCC_G4C4 10
# ISU-ILCC_G13C4 10
# ISU-ILCC_G46C3 17
# ISU-ILCC_G38C2 5
# ISU-ILCC_G34C1 17
# ISU-ILCC_G45C4 5
# ISU-ILCC_G27C4 2
# ISU-ILCC_G35C1 5
# ISU-ILCC_G21C4 5
# ISU-ILCC_G24C1 5
# ISU-ILCC_G40C4 2
# ISU-ILCC_G42C3 2
# ISU-ILCC_G39C1 5
# ISU-ILCC_G14C1 10
# ISU-ILCC_G61C2 17
# ISU-ILCC_G63C3 17
# ISU-ILCC_G23C4 5
# ISU-ILCC_G36C1 5
# ISU-ILCC_G57C2 17
# ISU-ILCC_G55C1 17
# ISU-ILCC_G4C1 10
# ISU-ILCC_G7C3 10
# ISU-ILCC_G12C4 10
# ISU-ILCC_G34C2 17
# ISU-ILCC_G7C1 10
# ISU-ILCC_G51C4 17
# ISU-ILCC_G4C2 10
# ISU-ILCC_G44C1 2
# ISU-ILCC_G46C4 17
# ISU-ILCC_G42C2 2
# ISU-ILCC_G28C2 17
# ISU-ILCC_G12C3 10
# ISU-ILCC_G51C2 17
# ISU-ILCC_G62C4 17
# ISU-ILCC_G30C2 17
# ISU-ILCC_G28C1 17
# ISU-ILCC_G56C2 10
# ISU-ILCC_G23C2 5
# ISU-ILCC_G52C1 10
# ISU-ILCC_G37C3 5
# ISU-ILCC_G34C3 17
# ISU-ILCC_G57C3 17
# ISU-ILCC_G32C2 17
# ISU-ILCC_G38C3 5
# ISU-ILCC_G18C3 2
# ISU-ILCC_G10C3 2
# ISU-ILCC_G40C3 17
# ISU-ILCC_G14C3 10
# ISU-ILCC_G1C4 2
# ISU-ILCC_G29C2 2
# ISU-ILCC_G17C3 10
# ISU-ILCC_G45C1 2
# ISU-ILCC_G62C3 17
# ISU-ILCC_G31C3 2
# ISU-ILCC_G25C3 10
# ISU-ILCC_G44C4 2
# ISU-ILCC_G4C3 10
# ISU-ILCC_G44C2 2
# ISU-ILCC_G62C1 17
# ISU-ILCC_G30C3 17
# ISU-ILCC_G56C3 10
# ISU-ILCC_G47C4 17
# ISU-ILCC_G25C2 2
# ISU-ILCC_G42C1 2
# ISU-ILCC_G20C1 5
# ISU-ILCC_G59C1 2
# ISU-ILCC_G38C4 5
# ISU-ILCC_G9C3 5
# ISU-ILCC_G35C3 5
# ISU-ILCC_G8C4 10
# ISU-ILCC_G53C1 5
# ISU-ILCC_G30C4 17
# ISU-ILCC_G20C3 5
# ISU-ILCC_G9C1 5
# ISU-ILCC_G21C1 5
# ISU-ILCC_G3C2 17
# ISU-ILCC_G5C1 5
# ISU-ILCC_G1C3 2
# ISU-ILCC_G62C2 17
# ISU-ILCC_G58C3 10
# ISU-ILCC_G21C2 5
# ISU-ILCC_G28C4 17
# ISU-ILCC_G24C2 5
# CALCE_CS2_36 5
# CALCE_CS2_37 5
# CALCE_CX2_33 5
# CALCE_CS2_34 5
# CALCE_CX2_37 5
# CALCE_CS2_33 5
# CALCE_CS2_35 5
# CALCE_CS2_38 5
# CALCE_CX2_36 5
# HNEI_18650_NMC_LCO_25C_0-100_0.5-1.5C_o 12
# HNEI_18650_NMC_LCO_25C_0-100_0.5-1.5C_p 12
# HNEI_18650_NMC_LCO_25C_0-100_0.5-1.5C_e 12
# HNEI_18650_NMC_LCO_25C_0-100_0.5-1.5C_l 12
# HNEI_18650_NMC_LCO_25C_0-100_0.5-1.5C_b 12
# HNEI_18650_NMC_LCO_25C_0-100_0.5-1.5C_t 12
# HNEI_18650_NMC_LCO_25C_0-100_0.5-1.5C_c 12
# HNEI_18650_NMC_LCO_25C_0-100_0.5-1.5C_a 12
# HNEI_18650_NMC_LCO_25C_0-100_0.5-1.5C_g 12
# SNL_18650_NCA_25C_0-100_0.5-0.5C_b 1
# SNL_18650_NCA_35C_0-100_0.5-1C_b 1
# SNL_18650_NMC_35C_0-100_0.5-2C_b 15
# SNL_18650_NMC_25C_0-100_0.5-3C_b 15
# SNL_18650_NMC_25C_0-100_0.5-1C_a 15
# SNL_18650_LFP_25C_0-100_0.5-3C_c 15
# SNL_18650_NCA_25C_0-100_0.5-2C_b 1
# SNL_18650_NMC_15C_0-100_0.5-2C_b 15
# SNL_18650_LFP_35C_0-100_0.5-1C_d 15
# SNL_18650_NCA_35C_0-100_0.5-1C_a 1
# SNL_18650_LFP_35C_0-100_0.5-2C_b 15
# SNL_18650_NMC_25C_0-100_0.5-1C_c 15
# SNL_18650_NMC_25C_0-100_0.5-3C_a 15
# SNL_18650_NCA_35C_0-100_0.5-1C_d 1
# SNL_18650_NMC_25C_0-100_0.5-1C_d 15
# SNL_18650_LFP_25C_0-100_0.5-3C_a 15
# SNL_18650_NCA_15C_0-100_0.5-2C_a 1
# SNL_18650_NMC_25C_0-100_0.5-2C_a 15
# SNL_18650_NCA_35C_0-100_0.5-1C_c 1
# SNL_18650_NCA_15C_0-100_0.5-1C_b 1
# SNL_18650_NCA_35C_0-100_0.5-2C_a 1
# SNL_18650_LFP_25C_0-100_0.5-3C_d 15
# SNL_18650_NCA_15C_0-100_0.5-1C_a 1
# SNL_18650_NMC_35C_0-100_0.5-2C_a 15
# SNL_18650_NMC_15C_0-100_0.5-2C_a 15
# SNL_18650_NCA_25C_20-80_0.5-0.5C_c 7
# SNL_18650_NMC_25C_0-100_0.5-2C_b 15
# SNL_18650_NMC_25C_0-100_0.5-0.5C_b 1
# SNL_18650_NMC_35C_0-100_0.5-1C_a 15
# SNL_18650_LFP_35C_0-100_0.5-1C_b 15
# MICH_BLForm2_pouch_NMC_45C_0-100_1-1C_b 16
# MICH_BLForm1_pouch_NMC_45C_0-100_1-1C_a 16
# MICH_MCForm32_pouch_NMC_45C_0-100_1-1C_b 9
# MICH_MCForm27_pouch_NMC_25C_0-100_1-1C_g 9
# MICH_MCForm22_pouch_NMC_25C_0-100_1-1C_b 9
# MICH_MCForm36_pouch_NMC_45C_0-100_1-1C_f 9
# MICH_MCForm29_pouch_NMC_25C_0-100_1-1C_i 9
# MICH_MCForm39_pouch_NMC_45C_0-100_1-1C_i 9
# MICH_BLForm5_pouch_NMC_45C_0-100_1-1C_e 16
# MICH_BLForm16_pouch_NMC_25C_0-100_1-1C_f 16
# MICH_MCForm30_pouch_NMC_25C_0-100_1-1C_j 9
# MICH_BLForm14_pouch_NMC_25C_0-100_1-1C_d 16
# MICH_MCForm38_pouch_NMC_45C_0-100_1-1C_h 9
# MICH_BLForm8_pouch_NMC_45C_0-100_1-1C_h 16
# MICH_BLForm17_pouch_NMC_25C_0-100_1-1C_g 16
# MICH_MCForm23_pouch_NMC_25C_0-100_1-1C_c 9
# MICH_BLForm18_pouch_NMC_25C_0-100_1-1C_h 16
# MICH_BLForm10_pouch_NMC_25C_0-100_1-1C_j 16
# MICH_MCForm35_pouch_NMC_45C_0-100_1-1C_e 9
# MICH_MCForm25_pouch_NMC_25C_0-100_1-1C_e 9
# MICH_MCForm26_pouch_NMC_25C_0-100_1-1C_f 9
# MICH_MCForm37_pouch_NMC_45C_0-100_1-1C_g 9
# MICH_BLForm15_pouch_NMC_25C_0-100_1-1C_e 16
# MICH_MCForm31_pouch_NMC_45C_0-100_1-1C_a 9
# MICH_11C_pouch_NMC_-5C_0-100_0.2-1.5C 8
# MICH_02C_pouch_NMC_-5C_0-100_0.2-0.2C 8
# MICH_04R_pouch_NMC_25C_0-100_1.5-1.5C 8
# MICH_03H_pouch_NMC_45C_0-100_0.2-0.2C 8
# MICH_08C_pouch_NMC_-5C_0-100_2-2C 8
# MICH_10R_pouch_NMC_25C_0-100_0.2-1.5C 8
# MICH_12H_pouch_NMC_45C_0-100_0.2-1.5C 8
# XJTU_2C_battery-6 11
# XJTU_2C_battery-2 11
# XJTU_3C_battery-2 11
# XJTU_3C_battery-3 11
# XJTU_3C_battery-10 11
# XJTU_3C_battery-13 11
# XJTU_3C_battery-7 11
# XJTU_3C_battery-15 11
# XJTU_3C_battery-4 11
# XJTU_3C_battery-5 11
# XJTU_3C_battery-11 11
# XJTU_3C_battery-6 11
# XJTU_2C_battery-1 11
# XJTU_2C_battery-8 11
# XJTU_2C_battery-4 11
