# %%
import os
import sys
folder_a_path = os.path.abspath(os.path.join(os.getcwd(), '..'))
sys.path.append(folder_a_path)
import json
import pickle
import matplotlib.pyplot as plt
from data_provider.data_split_recorder import split_recorder

# %%
data_path = '/data/trf/python_works/BatteryLife/dataset/ZN-coin'
zn_files = os.listdir(data_path)
zn_files
# Out:
# ['ZN-coin_437-2_20231227204712_04_1.pkl',
#  'ZN-coin_446-1_20240104212538_07_2.pkl',
#  'ZN-coin_204-2_20231205230217_07_2.pkl',
#  'ZN-coin_429-1_20231212185129_01_5.pkl',
#  'ZN-coin_427-1_20231205230153_03_7.pkl',
#  'ZN-coin_402-2_20231209225727_01_2.pkl',
#  'ZN-coin_416-3_20231209233856_10_5.pkl',
#  'ZN-coin_405-3_20231209231450_08_4.pkl',
#  'ZN-coin_453-1_20240116203617_08_6_Batch-3.pkl',
#  'ZN-coin_421-1_20231205230023_01_4.pkl',
#  'ZN-coin_450-3_20240116203417_03_3_Batch-3.pkl',
#  'ZN-coin_440-3_20231227204837_08_3.pkl',
#  'ZN-coin_436-1_20231227204646_03_5.pkl',
#  'ZN-coin_445-2_20240104212521_09_8.pkl',
#  'ZN-coin_441-1_20231227204855_08_4.pkl',
#  'ZN-coin_412-3_20231209233120_06_1.pkl',
#  'ZN-coin_433-1_20231227204534_01_4.pkl',
#  'ZN-coin_414-2_20231209233354_06_6.pkl',
#  'ZN-coin_438-1_20231227204743_04_3.pkl',
#  'ZN-coin_417-3_20231209234058_10_8.pkl',
#  'ZN-coin_442-3_20240104212433_09_3.pkl',
#  'ZN-coin_423-3_20231205230102_02_4.pkl',
# ...

# %%
for file in zn_files:
    data = pickle.load(open(f'{data_path}/{file}', 'rb'))
    print(data['nominal_capacity_in_Ah'])
# Out:
# 0.00022168368101119996
# 0.0003418417870998383
# 0.0004526075124740601
# 0.00047336381673812865
# 0.00028273671865463256
# 0.0004193820655345917
# 0.0004206445813179016
# 0.00039630037546157837
# 0.00021058979630470277
# 0.0002961892485618591
# 0.00034497278928756714
# 0.0003691455125808716
# 0.00022195017337799073
# 0.00041241684556007387
# 0.00024173340201377868
# 0.00037107181549072264
# 0.00032050311565399173
# 0.00041905203461647033
# 0.00022805438935756683
# 0.0003942461907863617
# 0.0003827188611030579
# 0.00033713558316230774
# 0.0004311908483505249
# 0.00021888884902000427
# 0.0002969532907009125
# 0.0003036242425441742
# 0.00041197261214256285
# 0.00038796445727348327
# 0.00031906595826148985
# 0.0003798752427101135
# 0.0003534259796142578
# 0.00022350119054317474
# 0.0002361009418964386
# 0.00038651281595230105
# 0.00037687647342681885
# 0.00034152165055274965
# 0.0003428637385368347
# 0.00031282302737236023
# 0.00033882397413253785
# 0.00032712620496749877
# ...
